# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pprint

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/categories'

parameters = {
  'start':'1',
  'limit':'200',
}

headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY':'8c500e61-7160-4289-8b71-5dd0a12c9c29'

}

session = Session()
session.headers.update(headers) 

response = session.get(url, params=parameters)
data = pprint.pprint(json.loads(response.text))
# Out:
# {'data': [{'avg_price_change': 1.0190995409090908,
#            'description': 'Icetea Labs',
#            'id': '6113ca776ea42668462d34de',
#            'last_updated': '2021-08-12T04:16:50.807Z',
#            'market_cap': 96660364.77000001,
#            'market_cap_change': 1.140218181818182,
#            'name': 'Icetea Labs',
#            'num_tokens': 13,
#            'title': 'Icetea Labs',
#            'volume': 20393474.58311889,
#            'volume_change': 38.378063636363635},
#           {'avg_price_change': 2.201319802626262,
#            'description': 'Play to Earn',
#            'id': '60fb6ba4ee872d7cfdd7556d',
#            'last_updated': '2021-08-05T17:42:45.851Z',
#            'market_cap': 12304028720.160002,
#            'market_cap_change': -0.11213333333333343,
#            'name': 'Play to Earn',
#            'num_tokens': 118,
#            'title': 'Play to Earn',
#            'volume': 3428223327.1361647,
#            'volume_change': 97.75060606060606},
# ...

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pprint

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/category'

parameters = {
  'id':'6051a82566fc1b42617d6dc6',  
  'limit':'200'
}

headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY':'8c500e61-7160-4289-8b71-5dd0a12c9c29'

}

session = Session()
session.headers.update(headers) 

response = session.get(url, params=parameters)
data = pprint.pprint(json.loads(response.text))
# Out:
# {'data': {'avg_price_change': 6.656413825546215,
#           'coins': [{'circulating_supply': 131542299402.88884,
#                      'cmc_rank': 10,
#                      'date_added': '2013-12-15T00:00:00.000Z',
#                      'id': 74,
#                      'is_active': 1,
#                      'is_fiat': 0,
#                      'last_updated': '2021-10-03T10:05:03.000Z',
#                      'max_supply': None,
#                      'name': 'Dogecoin',
#                      'num_market_pairs': 394,
#                      'platform': None,
#                      'quote': {'USD': {'fully_diluted_market_cap': 28553090981.82,
#                                        'last_updated': '2021-10-03T10:05:03.000Z',
#                                        'market_cap': 28553090981.821224,
#                                        'market_cap_dominance': 1.3448,
#                                        'percent_change_1h': -0.5187341,
# ...
